# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
X = df.drop(['id'],axis=1)

# %%
X1 = X[['radius_mean','texture_mean','diagnosis']]

# %%
X1.head()
# Out:
#    radius_mean  texture_mean diagnosis
# 0        17.99         10.38         M
# 1        20.57         17.77         M
# 2        19.69         21.25         M
# 3        11.42         20.38         M
# 4        20.29         14.34         M

# %%
import seaborn as sns

# %%
g =sns.scatterplot(x="radius_mean", y="texture_mean",
              hue="diagnosis",
              data=X1);

# %%
X2 = X[['texture_mean','perimeter_mean','diagnosis']]

# %%
X2.head()
# Out:
#    texture_mean  perimeter_mean diagnosis
# 0         10.38          122.80         M
# 1         17.77          132.90         M
# 2         21.25          130.00         M
# 3         20.38           77.58         M
# 4         14.34          135.10         M

# %%
g =sns.scatterplot(x="texture_mean", y="perimeter_mean",
              hue="diagnosis",
              data=X2);
